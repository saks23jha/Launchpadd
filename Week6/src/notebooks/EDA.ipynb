# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("/home/sakshijha/Desktop/LaunchPad/Week6/src/data/processed/final.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            3         1       3
# 2            4         1       1
# 3            5         0       3
# 4            6         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                       Braund, Mr. Owen Harris    male  22.0      1      0
# 1                        Heikkinen, Miss. Laina  female  26.0      0      0
# 2  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 3                      Allen, Mr. William Henry    male  35.0      0      0
# 4                              Moran, Mr. James    male  28.0      0      0
#
#              Ticket     Fare Embarked
# 0         A/5 21171   7.2500        S
# 1  STON/O2. 3101282   7.9250        S
# 2            113803  53.1000        S
# 3            373450   8.0500        S
# 4            330877   8.4583        Q

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# %%
df.hist(figsize=(12,8))
plt.suptitle("Feature Distributions")
plt.show()

# %%
sns.countplot(x="Survived", data=df)
plt.title("Target Distribution")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.isnull(), cbar=False)
plt.title("Missing Values Heatmap")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("/home/sakshijha/Desktop/LaunchPad/Week6/src/data/processed/final.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            3         1       3
# 2            4         1       1
# 3            5         0       3
# 4            6         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                       Braund, Mr. Owen Harris    male  22.0      1      0
# 1                        Heikkinen, Miss. Laina  female  26.0      0      0
# 2  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 3                      Allen, Mr. William Henry    male  35.0      0      0
# 4                              Moran, Mr. James    male  28.0      0      0
#
#              Ticket     Fare Embarked
# 0         A/5 21171   7.2500        S
# 1  STON/O2. 3101282   7.9250        S
# 2            113803  53.1000        S
# 3            373450   8.0500        S
# 4            330877   8.4583        Q

# %%
df.shape
# Out:
# (775, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 775 entries, 0 to 774
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  775 non-null    int64
#  1   Survived     775 non-null    int64
#  2   Pclass       775 non-null    int64
#  3   Name         775 non-null    object
#  4   Sex          775 non-null    object
#  5   Age          775 non-null    float64
#  6   SibSp        775 non-null    int64
#  7   Parch        775 non-null    int64
#  8   Ticket       775 non-null    object
#  9   Fare         775 non-null    float64
#  10  Embarked     775 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 66.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived     Pclass         Age       SibSp       Parch  \
# count   775.000000  775.000000  775.00000  775.000000  775.000000  775.000000
# mean    445.806452    0.339355    2.48000   28.748710    0.437419    0.340645
# std     260.116285    0.473796    0.73439   12.782123    0.899838    0.785914
# min       1.000000    0.000000    1.00000    0.420000    0.000000    0.000000
# 25%     213.500000    0.000000    2.00000   22.000000    0.000000    0.000000
# 50%     450.000000    0.000000    3.00000   28.000000    0.000000    0.000000
# 75%     670.500000    1.000000    3.00000   34.000000    1.000000    0.000000
# max     891.000000    1.000000    3.00000   80.000000    5.000000    6.000000
#
#              Fare
# count  775.000000
# mean    17.822091
# std     13.578085
# min      0.000000
# 25%      7.895800
# 50%     13.000000
# 75%     26.000000
# max     65.000000

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

numeric_df = df.select_dtypes(include=[np.number])

plt.figure(figsize=(12, 6))
sns.boxplot(data=numeric_df)
plt.title("Outlier Detection")
plt.xticks(rotation=45)
plt.show()

# %%
raw = pd.read_csv("../data/raw/titanic.csv")
processed = pd.read_csv("../data/processed/final.csv")

print("Max Fare (raw):", raw["Fare"].max())
print("Max Fare (processed):", processed["Fare"].max())
# Out:
# Max Fare (raw): 512.3292
# Max Fare (processed): 65.0

# %%
raw = pd.read_csv("../data/raw/titanic.csv")

sns.boxplot(y=raw["Fare"])
plt.title("Fare Outliers in Raw Data")
plt.show()

# %%
print("Max Fare (raw):", raw["Fare"].max())
print("Max Fare (processed):", processed["Fare"].max())
# Out:
# Max Fare (raw): 512.3292
# Max Fare (processed): 65.0

# %%
processed = pd.read_csv("../data/processed/final.csv")

sns.boxplot(y=processed["Fare"])
plt.title("Fare After Outlier Removal")
plt.show()
